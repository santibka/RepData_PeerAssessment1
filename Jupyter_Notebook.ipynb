# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Karina Santibanez**
#
# Data Engineer

# %% [markdown]
# *I am interested in data science because I think it's a discipline to uncover actionable insights hidden in the data that can help organizations guide decision making and strategic planning.*

# %% [markdown]
# ### Print Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ---
# * Unordered sub-list
# * Unordered sub-list
# * Unordered sub-list
#
# |Col1|Col2|Col3|
# |--|--|--|
# |Row1|Row1|Row1|
# |Row2|Row2|Row2|
# |Row3|Row3|Row3|
